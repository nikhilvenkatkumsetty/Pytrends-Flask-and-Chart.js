# %%
from pytrends.request import TrendReq
import pandas as pd
import time
startTime = time.time()
pytrend = TrendReq(hl='en-IN', tz=360)

# %%
colnames = ["list"]
df = pd.read_csv("list.csv", names=colnames)
df2 = df["list"].values.tolist()
df2.remove("list")

dataset = []

# %%
for x in range(0,len(df2)):
    words = [df2[x]]
    pytrend.build_payload(kw_list=words,cat=0,timeframe='2020-01-01 2020-06-01',geo='IN')
    data = pytrend.interest_over_time()
    if not data.empty:
        data = data.drop(labels=['isPartial'],axis='columns')
        dataset.append(data)

# %%
result = pd.concat(dataset, axis=1)
result.to_csv('trends.csv')

# %%
import csv

with open('trends.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

print(data)
# Out:
# [['date', 'Parker pen'], ['2020-01-01', '53'], ['2020-01-02', '63'], ['2020-01-03', '62'], ['2020-01-04', '54'], ['2020-01-05', '61'], ['2020-01-06', '66'], ['2020-01-07', '70'], ['2020-01-08', '63'], ['2020-01-09', '61'], ['2020-01-10', '55'], ['2020-01-11', '46'], ['2020-01-12', '45'], ['2020-01-13', '56'], ['2020-01-14', '54'], ['2020-01-15', '57'], ['2020-01-16', '47'], ['2020-01-17', '34'], ['2020-01-18', '55'], ['2020-01-19', '51'], ['2020-01-20', '64'], ['2020-01-21', '50'], ['2020-01-22', '47'], ['2020-01-23', '82'], ['2020-01-24', '51'], ['2020-01-25', '75'], ['2020-01-26', '54'], ['2020-01-27', '23'], ['2020-01-28', '83'], ['2020-01-29', '57'], ['2020-01-30', '77'], ['2020-01-31', '38'], ['2020-02-01', '53'], ['2020-02-02', '60'], ['2020-02-03', '76'], ['2020-02-04', '69'], ['2020-02-05', '65'], ['2020-02-06', '100'], ['2020-02-07', '52'], ['2020-02-08', '67'], ['2020-02-09', '69'], ['2020-02-10', '64'], ['2020-02-11', '44'], ['2020-02-12', '36'], ['2020-02-13', '65'], ['2020-02-14', '70'], ['2020-02-15', '65'], ['2020-02-16', '44'], ['2020-02-17', '57'], ['2020-02-18', '62'], ['2020-02-19', '95'], ['2020-02-20', '97'], ['2020-02-21', '58'], ['2020-02-22', '60'], ['2020-02-23', '97'], ['2020-02-24', '58'], ['2020-02-25', '88'], ['2020-02-26', '68'], ['2020-02-27', '58'], ['2020-02-28', '52'], ['2020-02-29', '49'], ['2020-03-01', '64'], ['2020-03-02', '48'], ['